# %%
import rispy
import pandas as pd
from pathlib import Path
import os
import sys

# %%
# os.chdir("../")
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: D:\projects\MateReview\notebooks

# %%
filepath = Path("../data/REV1-SCOPUS-1/2026-03-26_Export.csv")
df = pd.read_csv(filepath, encoding="utf-8", header=0)
df.head()
# Out:
#                                              Authors  \
# 0                                 Li Z.; Scandolo S.
# 1  Yan J.; Bai L.; Liu H.; Zhang Z.; Tang Y.; Zha...
# 2                             Lv M.; Gu M.-Y.; Xu X.
# 3                  Lüthje J.T.; Langiu M.; Mitsos A.
# 4             Choi K.; Joe J.; Ha S.; Lee D.; Mun J.
#
#                                    Author full names  \
# 0   Li, Z. (57213002214); Scandolo, S. (35549702800)
# 1  Yan, Jiaxing (59154534900); Bai, Lele (5798571...
# 2  Lv, Min (60145366900); Gu, Meng-Yuan (60479684...
# 3  Lüthje, Jannik T. (57204522119); Langiu, Marco...
# 4  Choi, Kwangwon (58182397200); Joe, Jaewan (551...
#
#                                         Author(s) ID  \
# 0                           57213002214; 35549702800
# 1  59154534900; 57985715800; 57113931700; 6038952...
# 2              60145366900; 60479684000; 60479343000
# 3               57204522119; 57222180477; 8979766700
# ...

# %%
# Turn into dataframe
df.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Cited by', 'DOI', 'Link', 'Affiliations', 'Authors with affiliations',
#        'Abstract', 'Author Keywords', 'Index Keywords',
#        'Molecular Sequence Numbers', 'Chemicals/CAS', 'Tradenames',
#        'Manufacturers', 'Funding Details', 'Funding Texts', 'References',
#        'Correspondence Address', 'Editors', 'Publisher', 'Sponsors',
#        'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='str')

# %%
# Filter by year > 2021, type is Jurnal and has DOI
filtered_df = df[(df["year"].astype(int) > 2021) & (df["type_of_reference"] == "JOUR") & (df["doi"].notna())]
print(f"Filtered entries: {len(filtered_df)}")
filtered_df.head()
# Out:
# Filtered entries: 3763
#   type_of_reference                                            authors  \
# 0              JOUR                             [Li, Z., Scandolo, S.]
# 1              JOUR  [Yan, J., Bai, L., Liu, H., Zhang, Z., Tang, Y...
# 3              JOUR             [Lüthje, J.T., Langiu, M., Mitsos, A.]
# 4              JOUR      [Choi, K., Joe, J., Ha, S., Lee, D., Mun, J.]
# 5              JOUR                                  [Kumar Yadav, A.]
#
#                                                title  year  \
# 0  A physics-informed long-range polarizable pote...  2026
# 1  In-Process Tool Wear Prediction Enabled by Phy...  2026
# 3  Working fluid screening for ORC-based Carnot b...  2026
# 4  A non-intrusive experimental study on the ther...  2026
# 5  Artificial Intelligence in Accelerating Materi...  2026
#
#                                secondary_title volume number custom7  \
# 0                  Journal of Chemical Physics    164      4  044107
# ...

# %%
filtered_df = df[(df["year"] > 2021) & (df["type_of_reference"] == "JOUR") & (df["doi"].notna())]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 filtered_df = df[(df["year"] > 2021) & (df["type_of_reference"] == "JOUR") & (df["doi"].notna())]
#
# File D:\projects\MateReview\.venv\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File D:\projects\MateReview\.venv\Lib\site-packages\pandas\core\arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File D:\projects\MateReview\.venv\Lib\site-packages\pandas\core\series.py:6735, in Series._cmp_method(self, other, op)
#    6732 lvalues = self._values
# ...
